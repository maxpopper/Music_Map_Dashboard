# %% [markdown]
# # <center> API Youtube Scrape

# %%
from googleapiclient.discovery import build
import pandas as pd
import datetime as dt

# %%
api_key='xxxx'

# Latin America Artist Channel ID
Bad_Bunny='UCmBA_wu8xGg1OfOkfW13Q0Q'
Peso_Pluma='UCzrM_068Odho89mTRrrxqbA'
Feid='UCoMlNw7o21I7LqL4OsjSYAg'
KarolG= 'UCZuPJZ2kGFdlbQu1qotZaHw'

# African Artist Channel ID
Burna_boy='UCEzDdNqNkT-7rSfSGSr1hWg'
Tyla='UC8HOgNWipVorrlBH8oN2R-A'
Wizkid='UCi7Cbr-F3zFQjwafFh5RWJA'
Rema = 'UCHGF6zfD2gwLuke95X3CKFQ'

# Us/Canada Artist Channel ID
ts_channel_id = 'UCqECaJ8Gagnn7YCbPEzWH6g'
drake_channel_id = 'UCByOQJjav0CUDwxCk-jVNRQ'
weeknd_channel_id = 'UC0WP5P-ufpRfjbNrmOWwLBQ'
beyonce_channel_id = 'UCuHzBCaKmtaLcRAOoazhCPA'

# South korea Artist Channel ID
bts_channel_id = 'UCLkAepWjdylmXSltofFvsYQ'
blackpink_channel_id = 'UCOmHUn--16B90oW2L6FRR3A'
twice_channel_id = 'UCzgxx_DM2Dcb9Y1spb9mUJA'
exo_channel_id = 'UCzCedBCSSltI1TFd3bKyN6g'

# UK Artist Channel ID
Ed_Sheeran_channel_id = 'UC0C-w0YjGpqDXGB8IHb662A'
Harry_styles_channel_id = 'UCZFWPqqPkFlNwIxcpsLOwew'
Adele_channel_id = 'UCsRM0YB_dabtEPGPTKo-gcw'
Dua_Lipa_channel_id = 'UC-J-KZfRV8c13fOCkhXdLiQ'


youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# ### <center> Regions - Artists
# #### <left>Latin Artists: Bad Bunny, Peso Pluma, Feid, Karol G
# #### <left>African Artists: Burna boy, Tyla, Wizkid, Rema
# #### <left>Us/Canada Artists: Taylor Swift, Drake, Weekend, Beyonce
# #### <left>South korea Artists: BTS, Blackpink, Twice, Exo
#
# ### <center> Metrics Each Artist
# 1. Channel Name
# 2. Total Suscribers
# 3. Total Videos
# 4. Total Views
# 5. Average View per video
# 6. Average Videos per year
# 7. Channel Creation Date

# %%
def get_channel_stats(youtube, channel_id):
    request = youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=channel_id)
    response = request.execute()
    
    total_videos = int(response['items'][0]['statistics']['videoCount'])
    
    total_views = int(response['items'][0]['statistics']['viewCount'])
    visual_views = int(response['items'][0]['statistics']['viewCount'].replace(',', ''))
    
    subscriber_count = int(response['items'][0]['statistics']['subscriberCount'])
    visual_suscribers = int(response['items'][0]['statistics']['subscriberCount'].replace(',', ''))
    
    video_count = int(response['items'][0]['statistics']['videoCount'])
    visual_videos = int(response['items'][0]['statistics']['videoCount'].replace(',', ''))

    
    Data = {
        'Artist': response['items'][0]['snippet']['title'],
        'country': response['items'][0]['snippet'].get('country', 'Unknown'),  # Fetch country or set default to 'Unknown'
        'int_suscribers': subscriber_count,
        'str_suscribers': '{:,}'.format(visual_suscribers),
        'int_videos': total_videos,
        'str_videos': '{:,}'.format(visual_videos),
        'int_views': total_views,
        'str_views': '{:,}'.format(visual_views),
        'channel_creation_date': (pd.to_datetime(response['items'][0]['snippet']['publishedAt'])).strftime("%Y-%m-%d")
            }
    Data['int_Average_views_per_video'] = round(total_views / video_count, 1)
    Data['str_Average_views_per_video'] = '{:,.1f}'.format(round(total_views / video_count, 1))
    Data['Average_videos_per_year'] = round(video_count / ((dt.datetime.now().year - pd.to_datetime(Data['channel_creation_date']).year) + 1), 1)
    return Data

# %%
LA_id_list = [Bad_Bunny,Peso_Pluma,Feid,KarolG]
LA_data=[]

for i in LA_id_list:
    artist_data = get_channel_stats(youtube, i)
    artist_data['region'] = 'Latin America'  # Add the 'region' key with value 'Latin America'
    LA_data.append(artist_data)
    
#Bad Bunny Town & Coordinates
LA_data[0]['from']= 'Almirante Sur, Puerto Rico'
LA_data[0]['coordinates']=[18.3763, 66.3825]
LA_data[0]['img_code'] = "align='center'> <img src='images/badbunny.jpg' width='200' height='200'"


#Peso Pluma Town & Coordinates
LA_data[1]['from']= 'Guadalajara, Mexico'
LA_data[1]['coordinates']= [20.6752, 103.3473]
LA_data[1]['img_code'] = "align='center'> <img src='images/pesopluma.jpg' width='200' height='200'"

    
#Feid Town & Coordinates
LA_data[2]['country']= 'CO'
LA_data[2]['from']= 'Medellin, Colombia'
LA_data[2]['coordinates']= [6.2476, 75.5658]
LA_data[2]['img_code'] = "align='center'> <img src='images/feid.jpg' width='200' height='200'"

    
#KarolG Town & Coordinates
LA_data[3]['from']= 'Medellin, Colombia'
LA_data[3]['coordinates']= [2.2476, 70.5658]
LA_data[3]['img_code'] = "align='center'> <img src='images/karolg.png' width='200' height='200'"

           
print(f'Latin American Artists Metrics:')
LA_data
# Out:
# Latin American Artists Metrics:
# [{'Artist': 'Bad Bunny',
#   'country': 'PR',
#   'int_suscribers': 47600000,
#   'str_suscribers': '47,600,000',
#   'int_videos': 154,
#   'str_videos': '154',
#   'int_views': 33977642604,
#   'str_views': '33,977,642,604',
#   'channel_creation_date': '2014-06-09',
#   'int_Average_views_per_video': 220634042.9,
#   'str_Average_views_per_video': '220,634,042.9',
#   'Average_videos_per_year': 14.0,
#   'region': 'Latin America',
#   'from': 'Almirante Sur, Puerto Rico',
#   'coordinates': [18.3763, 66.3825],
#   'img_code': "align='center'> <img src='images/badbunny.jpg' width='200' height='200'"},
#  {'Artist': 'Peso Pluma',
#   'country': 'MX',
#   'int_suscribers': 5380000,
#   'str_suscribers': '5,380,000',
#   'int_videos': 140,
#   'str_videos': '140',
#   'int_views': 3777929590,
#   'str_views': '3,777,929,590',
#   'channel_creation_date': '2023-01-24',
#   'int_Average_views_per_video': 26985211.4,
#   'str_Average_views_per_video': '26,985,211.4',
#   'Average_videos_per_year': 70.0,
#   'region': 'Latin America',
#   'from': 'Guadalajara, Mexico',
#   'coordinates': [20.6752, 103.3473],
#   'img_code': "align='center'> <img src='images/pesopluma.jpg' width='200' height='200'"},
#  {'Artist': 'Feid',
#   'country': 'CO',
#   'int_suscribers': 5840000,
#   'str_suscribers': '5,840,000',
#   'int_videos': 129,
#   'str_videos': '129',
#   'int_views': 6719832178,
#   'str_views': '6,719,832,178',
#   'channel_creation_date': '2011-08-13',
#   'int_Average_views_per_video': 52091722.3,
#   'str_Average_views_per_video': '52,091,722.3',
#   'Average_videos_per_year': 9.2,
#   'region': 'Latin America',
#   'from': 'Medellin, Colombia',
#   'coordinates': [6.2476, 75.5658],
#   'img_code': "align='center'> <img src='images/feid.jpg' width='200' height='200'"},
#  {'Artist': 'KAROL G',
#   'country': 'CO',
#   'int_suscribers': 35500000,
#   'str_suscribers': '35,500,000',
#   'int_videos': 159,
#   'str_videos': '159',
#   'int_views': 22708877353,
#   'str_views': '22,708,877,353',
#   'channel_creation_date': '2013-03-14',
#   'int_Average_views_per_video': 142823128.0,
#   'str_Average_views_per_video': '142,823,128.0',
#   'Average_videos_per_year': 13.2,
#   'region': 'Latin America',
#   'from': 'Medellin, Colombia',
#   'coordinates': [2.2476, 70.5658],
#   'img_code': "align='center'> <img src='images/karolg.jpg.jpeg' width='200' height='200'"}]

# %%
African_id_list = [Burna_boy,Tyla,Wizkid,Rema]
African_data=[]

for i in African_id_list:    
    artist_data = get_channel_stats(youtube, i)
    artist_data['region'] = 'Africa'  # Add the 'region' key with value 'Latin America'
    African_data.append(artist_data)
    
#Burna Boy Town & Coordinates
African_data[0]['country']= 'NG'
African_data[0]['from']= 'Port Harcourt, Nigeria'
African_data[0]['coordinates']=[4.8472, 6.9746]
African_data[0]['img_code'] = "align='center'> <img src='images/burnaboy.jpg' width='200' height='200'"

#Tyla Town & Coordinates
African_data[1]['from']= 'Johannesburg, South Africa'
African_data[1]['coordinates']= [26.2041, 28.0473]
African_data[1]['img_code'] = "align='center'> <img src='images/tyla.jpg' width='200' height='200'"

    
#Wizkid & Coordinates
African_data[2]['Artist']= 'WizKid'
African_data[2]['from']= 'Surulere, Lagos'
African_data[2]['coordinates']= [6.4926, 3.3490]
African_data[2]['img_code'] = "align='center'> <img src='images/wizkid.jpg' width='200' height='200'"

    
#Rema Town & Coordinates
African_data[3]['from']= 'Benin City, Edo, Nigeria'
African_data[3]['coordinates']= [6.335, 5.6037]
African_data[3]['img_code'] = "align='center'> <img src='images/rema.jpg' width='200' height='200'"


print(f'African Artists Metrics:')
African_data
# Out:
# African Artists Metrics:
# [{'Artist': 'Burna Boy',
#   'country': 'NG',
#   'int_suscribers': 4670000,
#   'str_suscribers': '4,670,000',
#   'int_videos': 253,
#   'str_videos': '253',
#   'int_views': 2658324064,
#   'str_views': '2,658,324,064',
#   'channel_creation_date': '2018-01-12',
#   'int_Average_views_per_video': 10507209.7,
#   'str_Average_views_per_video': '10,507,209.7',
#   'Average_videos_per_year': 36.1,
#   'region': 'Africa',
#   'from': 'Port Harcourt, Nigeria',
#   'coordinates': [4.8472, 6.9746],
#   'img_code': "align='center'> <img src='images/burnaboy.jpg' width='200' height='200'"},
#  {'Artist': 'Tyla',
#   'country': 'ZA',
#   'int_suscribers': 1250000,
#   'str_suscribers': '1,250,000',
#   'int_videos': 133,
#   'str_videos': '133',
#   'int_views': 387058507,
#   'str_views': '387,058,507',
#   'channel_creation_date': '2021-01-24',
#   'int_Average_views_per_video': 2910214.3,
#   'str_Average_views_per_video': '2,910,214.3',
#   'Average_videos_per_year': 33.2,
#   'region': 'Africa',
#   'from': 'Johannesburg, South Africa',
#   'coordinates': [26.2041, 28.0473],
#   'img_code': "align='center'> <img src='images/tyla.jpg' width='200' height='200'"},
#  {'Artist': 'WizKid',
#   'country': 'US',
#   'int_suscribers': 2990000,
#   'str_suscribers': '2,990,000',
#   'int_videos': 65,
#   'str_videos': '65',
#   'int_views': 1908820496,
#   'str_views': '1,908,820,496',
#   'channel_creation_date': '2014-09-20',
#   'int_Average_views_per_video': 29366469.2,
#   'str_Average_views_per_video': '29,366,469.2',
#   'Average_videos_per_year': 5.9,
#   'region': 'Africa',
#   'from': 'Surulere, Lagos',
#   'coordinates': [6.4926, 3.349],
#   'img_code': "align='center'> <img src='images/wizkid.jpg' width='200' height='200'"},
#  {'Artist': 'Rema',
#   'country': 'NG',
#   'int_suscribers': 4020000,
#   'str_suscribers': '4,020,000',
#   'int_videos': 128,
#   'str_videos': '128',
#   'int_views': 1517947332,
#   'str_views': '1,517,947,332',
#   'channel_creation_date': '2019-04-07',
#   'int_Average_views_per_video': 11858963.5,
#   'str_Average_views_per_video': '11,858,963.5',
#   'Average_videos_per_year': 21.3,
#   'region': 'Africa',
#   'from': 'Benin City, Edo, Nigeria',
#   'coordinates': [6.335, 5.6037],
#   'img_code': "align='center'> <img src='images/rema.jpg' width='200' height='200'"}]

# %%
us_can_id_list = [ts_channel_id, drake_channel_id, weeknd_channel_id, beyonce_channel_id]
us_can_data = []

for channel_id in us_can_id_list:
    us_can_data.append(get_channel_stats(youtube, channel_id))

us_can_data[0]['from'] = 'West Reading, Pennsylvania'
us_can_data[0]['coordinates'] = [40.3337, -75.9474]
us_can_data[0]['img_code'] = "align='center'> <img src='images/taylor_swift.jpeg' width='200' height='200'"

us_can_data[1]['from'] = 'Toronto, Canada'
us_can_data[1]['coordinates'] = [43.6532, -79.3832]
us_can_data[1]['img_code'] = "align='center'> <img src='images/Drake.jpeg' width='200' height='200'"

us_can_data[2]['from'] = 'Scarborough, Canada'
us_can_data[2]['coordinates'] = [43.7764, -79.2318]
us_can_data[2]['img_code'] = "align='center'> <img src='images/weeknd.jpeg' width='200' height='200'"

us_can_data[3]['from'] = 'Houston, Texas'
us_can_data[3]['coordinates'] = [29.7604, -95.3698]
us_can_data[3]['img_code'] = "align='center'> <img src='images/beyonce.jpeg' width='200' height='200'"

print(f'Us/Canada Artists Metrics:')
us_can_data
# Out:
# Us/Canada Artists Metrics:
# [{'Artist': 'Taylor Swift',
#   'country': 'Unknown',
#   'int_suscribers': 56700000,
#   'str_suscribers': '56,700,000',
#   'int_videos': 226,
#   'str_videos': '226',
#   'int_views': 33691814353,
#   'str_views': '33,691,814,353',
#   'channel_creation_date': '2006-09-20',
#   'int_Average_views_per_video': 149078824.6,
#   'str_Average_views_per_video': '149,078,824.6',
#   'Average_videos_per_year': 11.9,
#   'from': 'West Reading, Pennsylvania',
#   'coordinates': [40.3337, -75.9474],
#   'img_code': "align='center'> <img src='images/taylor_swift.jpeg' width='200' height='200'"},
#  {'Artist': 'Drake',
#   'country': 'Unknown',
#   'int_suscribers': 29300000,
#   'str_suscribers': '29,300,000',
#   'int_videos': 62,
#   'str_videos': '62',
#   'int_views': 17165624250,
#   'str_views': '17,165,624,250',
#   'channel_creation_date': '2009-06-05',
#   'int_Average_views_per_video': 276864907.3,
#   'str_Average_views_per_video': '276,864,907.3',
#   'Average_videos_per_year': 3.9,
#   'from': 'Toronto, Canada',
#   'coordinates': [43.6532, -79.3832],
#   'img_code': "align='center'> <img src='images/Drake.jpeg' width='200' height='200'"},
#  {'Artist': 'The Weeknd',
#   'country': 'CA',
#   'int_suscribers': 34600000,
#   'str_suscribers': '34,600,000',
#   'int_videos': 172,
#   'str_videos': '172',
#   'int_views': 26334925696,
#   'str_views': '26,334,925,696',
#   'channel_creation_date': '2011-02-25',
#   'int_Average_views_per_video': 153110033.1,
#   'str_Average_views_per_video': '153,110,033.1',
#   'Average_videos_per_year': 12.3,
#   'from': 'Scarborough, Canada',
#   'coordinates': [43.7764, -79.2318],
#   'img_code': "align='center'> <img src='images/weeknd.jpeg' width='200' height='200'"},
#  {'Artist': 'Beyoncé',
#   'country': 'Unknown',
#   'int_suscribers': 26700000,
#   'str_suscribers': '26,700,000',
#   'int_videos': 252,
#   'str_videos': '252',
#   'int_views': 18388043113,
#   'str_views': '18,388,043,113',
#   'channel_creation_date': '2005-11-07',
#   'int_Average_views_per_video': 72968425.1,
#   'str_Average_views_per_video': '72,968,425.1',
#   'Average_videos_per_year': 12.6,
#   'from': 'Houston, Texas',
#   'coordinates': [29.7604, -95.3698],
#   'img_code': "align='center'> <img src='images/beyonce.jpeg' width='200' height='200'"}]

# %%
korea_id_list = [bts_channel_id, blackpink_channel_id, twice_channel_id, exo_channel_id]
korea_data = []

for i in korea_id_list:
    korea_data.append(get_channel_stats(youtube, i))

korea_data[0]["Artist"] = "BTS"
korea_data[0]['from'] = 'Seoul, South Korea'
korea_data[0]['coordinates'] = [37.5519, 127.1028]
korea_data[0]['img_code'] = "align='center'> <img src='images/bts.jpeg' width='200' height='200'"

korea_data[1]['from'] = 'Seoul, South Korea'
korea_data[1]['coordinates'] = [37.4502, 127.1028]
korea_data[1]['img_code'] = "align='center'> <img src='images/blackpink.jpeg' width='200' height='200'"

korea_data[2]['from'] = 'Seoul, South Korea'
korea_data[2]['coordinates'] = [37.4519, 126.9911]
korea_data[2]['img_code'] = "align='center'> <img src='images/twice.jpeg' width='200' height='200'"

korea_data[3]['from'] = 'Seoul, South Korea'
korea_data[3]['coordinates'] = [37.5502, 126.9911]
korea_data[3]['img_code'] = "align='center'> <img src='images/exo.jpeg' width='200' height='200'"

print(f'South Korea Artists Metrics:')
korea_data
# Out:
# South Korea Artists Metrics:
# [{'Artist': 'BTS',
#   'country': 'Unknown',
#   'int_suscribers': 77500000,
#   'str_suscribers': '77,500,000',
#   'int_videos': 2450,
#   'str_videos': '2,450',
#   'int_views': 22285500770,
#   'str_views': '22,285,500,770',
#   'channel_creation_date': '2012-12-17',
#   'int_Average_views_per_video': 9096122.8,
#   'str_Average_views_per_video': '9,096,122.8',
#   'Average_videos_per_year': 188.5,
#   'from': 'Seoul, South Korea',
#   'coordinates': [37.5519, 127.1028],
#   'img_code': "align='center'> <img src='images/bts.jpeg' width='200' height='200'"},
#  {'Artist': 'BLACKPINK',
#   'country': 'KR',
#   'int_suscribers': 93100000,
#   'str_suscribers': '93,100,000',
#   'int_videos': 592,
#   'str_videos': '592',
#   'int_views': 34947503963,
#   'str_views': '34,947,503,963',
#   'channel_creation_date': '2016-06-29',
#   'int_Average_views_per_video': 59032945.9,
#   'str_Average_views_per_video': '59,032,945.9',
#   'Average_videos_per_year': 65.8,
#   'from': 'Seoul, South Korea',
#   'coordinates': [37.4502, 127.1028],
#   'img_code': "align='center'> <img src='images/blackpink.jpeg' width='200' height='200'"},
#  {'Artist': 'TWICE',
#   'country': 'Unknown',
#   'int_suscribers': 16900000,
#   'str_suscribers': '16,900,000',
#   'int_videos': 1448,
#   'str_videos': '1,448',
#   'int_views': 5833962871,
#   'str_views': '5,833,962,871',
#   'channel_creation_date': '2016-03-27',
#   'int_Average_views_per_video': 4028979.9,
#   'str_Average_views_per_video': '4,028,979.9',
#   'Average_videos_per_year': 160.9,
#   'from': 'Seoul, South Korea',
#   'coordinates': [37.4519, 126.9911],
#   'img_code': "align='center'> <img src='images/twice.jpeg' width='200' height='200'"},
#  {'Artist': 'EXO',
#   'country': 'KR',
#   'int_suscribers': 9630000,
#   'str_suscribers': '9,630,000',
#   'int_videos': 492,
#   'str_videos': '492',
#   'int_views': 1212896534,
#   'str_views': '1,212,896,534',
#   'channel_creation_date': '2006-12-10',
#   'int_Average_views_per_video': 2465236.9,
#   'str_Average_views_per_video': '2,465,236.9',
#   'Average_videos_per_year': 25.9,
#   'from': 'Seoul, South Korea',
#   'coordinates': [37.5502, 126.9911],
#   'img_code': "align='center'> <img src='images/exo.jpeg' width='200' height='200'"}]

# %%
uk_id_list = [Ed_Sheeran_channel_id, Harry_styles_channel_id, Adele_channel_id, Dua_Lipa_channel_id]
uk_data = []

for channel_id in uk_id_list:
    uk_data.append(get_channel_stats(youtube, channel_id))

uk_data[0]['from'] = 'Halifax, United Kingdom'
uk_data[0]['coordinates'] = [53.7270, 1.8575]
uk_data[0]['img_code'] = "align='center'> <img src='images/Edsheeran.jpeg' width='200' height='200'"

uk_data[1]['from'] = 'Redditch, United Kingdom'
uk_data[1]['coordinates'] = [52.3090, 1.9409]
uk_data[1]['img_code'] = "align='center'> <img src='images/Harrystyles.jpeg' width='200' height='200'"

uk_data[2]['from'] = 'Tottenham, London, United Kingdom'
uk_data[2]['coordinates'] = [51.6056, 0.0682 ]
uk_data[2]['img_code'] = "align='center'> <img src='images/Adele.jpeg' width='200' height='200'"

uk_data[3]['from'] = 'London, United Kingdom'
uk_data[3]['coordinates'] = [51.5072, 0.1276]
uk_data[3]['img_code'] = "align='center'> <img src='images/DuaLipa.jpeg' width='200' height='200'"

print(f'UK Artists Metrics:')
uk_data
# Out:
# UK Artists Metrics:
# [{'Artist': 'Ed Sheeran',
#   'country': 'Unknown',
#   'int_suscribers': 54200000,
#   'str_suscribers': '54,200,000',
#   'int_videos': 458,
#   'str_videos': '458',
#   'int_views': 31788646600,
#   'str_views': '31,788,646,600',
#   'channel_creation_date': '2006-08-08',
#   'int_Average_views_per_video': 69407525.3,
#   'str_Average_views_per_video': '69,407,525.3',
#   'Average_videos_per_year': 24.1,
#   'from': 'Halifax, United Kingdom',
#   'coordinates': [53.727, 1.8575],
#   'img_code': "align='center'> <img src='images/Edsheeran.jpeg' width='200' height='200'"},
#  {'Artist': 'Harry Styles',
#   'country': 'Unknown',
#   'int_suscribers': 14700000,
#   'str_suscribers': '14,700,000',
#   'int_videos': 17,
#   'str_videos': '17',
#   'int_views': 6278224388,
#   'str_views': '6,278,224,388',
#   'channel_creation_date': '2017-03-08',
#   'int_Average_views_per_video': 369307316.9,
#   'str_Average_views_per_video': '369,307,316.9',
#   'Average_videos_per_year': 2.1,
#   'from': 'Redditch, United Kingdom',
#   'coordinates': [52.309, 1.9409],
#   'img_code': "align='center'> <img src='images/Harrystyles.jpeg' width='200' height='200'"},
#  {'Artist': 'Adele',
#   'country': 'Unknown',
#   'int_suscribers': 31100000,
#   'str_suscribers': '31,100,000',
#   'int_videos': 15,
#   'str_videos': '15',
#   'int_views': 15281568777,
#   'str_views': '15,281,568,777',
#   'channel_creation_date': '2008-04-04',
#   'int_Average_views_per_video': 1018771251.8,
#   'str_Average_views_per_video': '1,018,771,251.8',
#   'Average_videos_per_year': 0.9,
#   'from': 'Tottenham, London, United Kingdom',
#   'coordinates': [51.6056, 0.0682],
#   'img_code': "align='center'> <img src='images/Adele.jpeg' width='200' height='200'"},
#  {'Artist': 'Dua Lipa',
#   'country': 'GB',
#   'int_suscribers': 23200000,
#   'str_suscribers': '23,200,000',
#   'int_videos': 210,
#   'str_videos': '210',
#   'int_views': 12662717494,
#   'str_views': '12,662,717,494',
#   'channel_creation_date': '2011-02-05',
#   'int_Average_views_per_video': 60298654.7,
#   'str_Average_views_per_video': '60,298,654.7',
#   'Average_videos_per_year': 15.0,
#   'from': 'London, United Kingdom',
#   'coordinates': [51.5072, 0.1276],
#   'img_code': "align='center'> <img src='images/DuaLipa.jpeg' width='200' height='200'"}]
